# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Polygon
# %matplotlib notebook
from ipywidgets import interact, interactive, fixed, interact_manual

# %% [markdown]
# We compiled the US States (and Washington DC) tax rates into one dataset from 2000-2023 based on the available information from the US Government. Then we added added it as a pandas DataFrame and rounded the numbers.

# %%
df = pd.read_csv("data05-22/taxrates.csv")
df = df.rename(columns={"State":"NAME", "STUSPS": "STATE"}).round(2)
df.head()
# Out:
#          NAME STATE  2005  2006  2007  2008  2009  2010  2011  2012  ...  \
# 0     Alabama    AL  6.50  6.50  6.50  6.50  6.50  6.50  6.50  6.50  ...
# 1      Alaska    AK  5.44  5.44  5.44  5.44  5.44  5.44  5.44  5.44  ...
# 2     Arizona    AZ  6.97  6.97  6.97  6.97  6.97  6.97  6.97  6.97  ...
# 3    Arkansas    AR  3.92  3.92  3.92  3.92  3.92  3.92  3.92  3.92  ...
# 4  California    CA  8.84  8.84  8.84  8.84  8.84  8.84  8.84  8.84  ...
#
#    2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# 0  6.50  6.50  6.50  6.50  6.50  6.50  6.50  6.50  6.50  6.50
# 1  5.44  5.34  5.34  5.34  5.34  5.34  5.34  5.34  5.34  5.34
# 2  6.50  5.50  5.50  4.90  4.90  4.90  4.90  4.90  4.90  4.90
# 3  3.92  3.92  3.92  3.92  3.92  3.92  3.92  3.87  3.65  3.55
# 4  8.84  8.84  8.84  8.84  8.84  8.84  8.84  8.84  8.84  8.84
#
# [5 rows x 21 columns]

# %% [markdown]
# To get an idea of the changes in the tax rates of each state, we transpose the data and plot a line graph using matplotlib.

# %%
df_t = df.T 
df_t.columns=df_t.iloc[0]
df_t = df_t.tail(-2)
df_t.head()
# Out:
# NAME Alabama Alaska Arizona Arkansas California Colorado Connecticut Delaware  \
# 2005     6.5   5.44    6.97     3.92       8.84     4.63         7.5      8.7
# 2006     6.5   5.44    6.97     3.92       8.84     4.63         7.5      8.7
# 2007     6.5   5.44    6.97     3.92       8.84     4.63         7.5      8.7
# 2008     6.5   5.44    6.97     3.92       8.84     4.63         7.5      8.7
# 2009     6.5   5.44    6.97     3.92       8.84     4.63         7.5      8.7
#
# NAME Florida Georgia  ... Tennessee Texas Utah Vermont Virginia Washington  \
# 2005     5.5     6.0  ...       6.5   0.0  5.0    8.51      6.0        0.0
# 2006     5.5     6.0  ...       6.5   4.5  5.0    8.51      6.0        0.0
# 2007     5.5     6.0  ...       6.5   4.5  5.0    7.66      6.0        0.0
# 2008     5.5     6.0  ...       6.5   1.0  5.0    7.17      6.0        0.0
# 2009     5.5     6.0  ...       6.5   0.0  5.0    7.17      6.0        0.0
#
# NAME West Virginia Wisconsin  Wyoming District of Columbia
# 2005           9.0        7.9     0.0                 9.98
# 2006           9.0        7.9     0.0                 9.98
# 2007           9.0        7.9     0.0                 9.98
# 2008          8.75        7.9     0.0                 9.98
# 2009           8.5        7.9     0.0                 9.98
#
# [5 rows x 51 columns]

# %%
# plot the data
ax = df_t.plot(figsize=(40,15))

# set x-axis label and values
ax.set_xlabel("Time")
ax.set_ylabel("Tax rate(%)")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="4000">

# %%
shapefile = 's_08mr23/s_08mr23.shp'
gdf = gpd.read_file(shapefile)
gdf
# Out:
#    STATE                      NAME FIPS         LON        LAT  \
# 0     AL                   Alabama   01  -86.826760  32.793540
# 1     AR                  Arkansas   05  -92.439200  34.899770
# 2     AS            American Samoa   60 -170.372150 -14.264860
# 3     AZ                   Arizona   04 -111.664570  34.293230
# 4     CA                California   06 -119.608180  37.245370
# 5     CO                  Colorado   08 -105.547830  38.998550
# 6     CT               Connecticut   09  -72.726230  41.621960
# 7     DC      District of Columbia   11  -77.014640  38.909320
# 8     DE                  Delaware   10  -75.505920  38.995590
# 9     FL                   Florida   12  -82.509340  28.674020
# 10    GA                   Georgia   13  -83.448480  32.651550
# 11    HI                    Hawaii   15 -156.347430  20.249230
# 12    IA                      Iowa   19  -93.500030  42.074630
# 13    ID                     Idaho   16 -114.659330  44.389070
# 14    IL                  Illinois   17  -89.198380  40.065010
# 15    IN                   Indiana   18  -86.275480  39.908010
# 16    KS                    Kansas   20  -98.380190  38.484710
# 17    KY                  Kentucky   21  -85.290460  37.526680
# 18    LA                 Louisiana   22  -92.029050  31.089100
# 19    MA             Massachusetts   25  -71.814230  42.257880
# 20    ME                     Maine   23  -69.229990  45.380460
# 21    MI                  Michigan   26  -85.436750  44.347170
# 22    MN                 Minnesota   27  -94.313570  46.311890
# 23    MS               Mississippi   28  -89.665530  32.752010
# 24    MT                   Montana   30 -109.645070  47.033500
# 25    NC            North Carolina   37  -79.378650  35.543690
# 26    ND              North Dakota   38 -100.469350  47.446260
# 27    NE                  Nebraska   31  -99.810580  41.527090
# 28    NH             New Hampshire   33  -71.577540  43.685560
# 29    NJ                New Jersey   34  -74.668760  40.200490
# 30    NM                New Mexico   35 -106.108370  34.421370
# 31    NV                    Nevada   32 -116.655390  39.356480
# 32    NY                  New York   36  -75.514910  42.947960
# 33    OH                      Ohio   39  -82.790020  40.291200
# 34    OK                  Oklahoma   40  -97.508190  35.583450
# 35    OR                    Oregon   41 -120.552320  43.935890
# 36    PA              Pennsylvania   42  -77.799300  40.873680
# 37    PR               Puerto Rico   72  -66.469120  18.222400
# 38    RI              Rhode Island   44  -71.555790  41.675440
# 39    SD              South Dakota   46 -100.230480  44.436140
# 40    TN                 Tennessee   47  -86.343320  35.842990
# 41    TX                     Texas   48  -99.359390  31.494220
# 42    UT                      Utah   49 -111.678220  39.323790
# 43    VA                  Virginia   51  -78.829570  37.516370
# 44    VI            Virgin Islands   78  -64.801280  17.963970
# 45    VT                   Vermont   50  -72.662730  44.075110
# 46    WA                Washington   53 -120.439970  47.380760
# 47    WI                 Wisconsin   55  -90.011440  44.637250
# 48    WV             West Virginia   54  -80.613720  38.642590
# 49    WY                   Wyoming   56 -107.551440  42.999630
# 50    MO                  Missouri   29  -92.385540  38.320800
# 51    SC            South Carolina   45  -80.898990  33.935740
# 52    GU                      Guam   66  145.157960  14.573840
# 53    MD                  Maryland   24  -76.785880  39.045330
# 54    PW                     Palau   70  134.511333   7.423531
# 55    MH          Marshall Islands   68  169.680752   7.460447
# 56    MP  Northern Mariana Islands   69  145.611142  15.776698
# 57    FM  Fed States of Micronesia   64  154.784715   7.089268
# 58    AK                    Alaska   02 -152.255721  64.242373
#
#                                              geometry
# 0   MULTIPOLYGON (((-88.11011 30.25891, -88.10638 ...
# 1   POLYGON ((-91.62986 36.49921, -91.62849 36.499...
# 2   MULTIPOLYGON (((-168.14924 -14.53377, -168.148...
# 3   POLYGON ((-110.49090 37.00361, -110.48750 37.0...
# 4   MULTIPOLYGON (((-118.42620 32.79973, -118.4263...
# 5   POLYGON ((-106.87560 41.00301, -106.85850 41.0...
# 6   MULTIPOLYGON (((-73.62247 40.98430, -73.62209 ...
# 7   MULTIPOLYGON (((-77.03097 38.80826, -77.03110 ...
# 8   MULTIPOLYGON (((-75.22731 38.58854, -75.22744 ...
# 9   MULTIPOLYGON (((-81.96339 24.52110, -81.96374 ...
# 10  MULTIPOLYGON (((-81.49619 30.73234, -81.49648 ...
# 11  MULTIPOLYGON (((-155.91183 19.18402, -155.9120...
# 12  POLYGON ((-92.44900 43.50181, -92.44550 43.500...
# 13  POLYGON ((-116.06000 49.00081, -116.04919 49.0...
# 14  POLYGON ((-90.64000 42.50841, -90.63660 42.508...
# 15  POLYGON ((-86.08849 41.76071, -86.06750 41.760...
# 16  POLYGON ((-101.87420 40.00311, -101.86520 40.0...
# 17  MULTIPOLYGON (((-89.48360 36.50021, -89.48499 ...
# 18  MULTIPOLYGON (((-89.41367 28.92076, -89.41422 ...
# 19  MULTIPOLYGON (((-70.81094 41.26176, -70.81018 ...
# 20  MULTIPOLYGON (((-70.42468 43.36591, -70.42200 ...
# 21  MULTIPOLYGON (((-83.43458 41.73714, -83.43464 ...
# 22  MULTIPOLYGON (((-92.20329 46.70404, -92.20239 ...
# 23  MULTIPOLYGON (((-88.62128 30.35913, -88.62421 ...
# 24  POLYGON ((-114.32130 49.00081, -114.26040 49.0...
# 25  MULTIPOLYGON (((-77.50814 34.45068, -77.50844 ...
# 26  POLYGON ((-97.23270 48.99921, -97.23390 48.996...
# 27  POLYGON ((-103.96180 43.00156, -103.96079 43.0...
# 28  POLYGON ((-71.08420 45.30531, -71.08210 45.288...
# 29  MULTIPOLYGON (((-74.90399 38.95216, -74.90373 ...
# 30  POLYGON ((-108.37560 36.99951, -108.35719 36.9...
# 31  POLYGON ((-114.81620 42.00201, -114.80900 42.0...
# 32  MULTIPOLYGON (((-73.72681 40.59421, -73.72669 ...
# 33  MULTIPOLYGON (((-82.65704 41.43713, -82.65740 ...
# 34  POLYGON ((-100.08950 37.00231, -100.05299 37.0...
# 35  MULTIPOLYGON (((-124.21268 42.00535, -124.2131...
# 36  MULTIPOLYGON (((-79.76220 42.26891, -79.76200 ...
# 37  MULTIPOLYGON (((-66.53116 17.88319, -66.53109 ...
# 38  MULTIPOLYGON (((-71.56863 41.22551, -71.56779 ...
# 39  POLYGON ((-102.64259 45.94541, -102.63840 45.9...
# 40  POLYGON ((-88.04480 36.67801, -88.02460 36.677...
# 41  MULTIPOLYGON (((-97.19970 25.99932, -97.19998 ...
# 42  POLYGON ((-111.04929 42.00161, -111.04680 42.0...
# 43  MULTIPOLYGON (((-77.92809 39.19681, -77.92400 ...
# 44  MULTIPOLYGON (((-64.76180 17.68474, -64.76116 ...
# 45  POLYGON ((-72.83210 45.01641, -72.82570 45.016...
# 46  MULTIPOLYGON (((-123.34106 46.15892, -123.3413...
# 47  MULTIPOLYGON (((-87.81677 42.59232, -87.81697 ...
# 48  POLYGON ((-80.52020 40.63791, -80.51900 40.634...
# 49  POLYGON ((-109.10339 45.00591, -109.08920 45.0...
# 50  POLYGON ((-91.72970 40.61361, -91.72010 40.601...
# 51  MULTIPOLYGON (((-82.38064 35.20132, -82.37949 ...
# 52  MULTIPOLYGON (((144.67462 13.23862, 144.67376 ...
# 53  MULTIPOLYGON (((-75.88359 37.90867, -75.88402 ...
# 54  MULTIPOLYGON (((131.81223 2.97520, 131.81258 2...
# 55  MULTIPOLYGON (((169.55728 5.82567, 169.55684 5...
# 56  MULTIPOLYGON (((145.14309 14.14635, 145.14262 ...
# 57  MULTIPOLYGON (((154.78084 1.02639, 154.77972 1...
# 58  MULTIPOLYGON (((-179.10756 51.30120, -179.1054...

# %%
#drop Puerto rico, Fed States of Micronesia, American Samoa, US Virgin Islands, Guam, Commonwealth of the northern mariana islands from file
gdf = gdf.drop(index=[2,37,44,52,54,55,56,57])
gdf = gdf.reset_index(drop=True)

# %%
len(gdf)
# Out:
# 51

# %%
gdf.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: >

# %% [markdown]
# Creating the merged dataset that will include the Tax rate as a column

# %%
df_test = df[['STATE','2022']].copy()
df_test.head()
# Out:
#   STATE  2022
# 0    AL  6.50
# 1    AK  5.34
# 2    AZ  4.90
# 3    AR  3.65
# 4    CA  8.84

# %%
gdf.head()
# Out:
#   STATE        NAME FIPS        LON       LAT  \
# 0    AL     Alabama   01  -86.82676  32.79354
# 1    AR    Arkansas   05  -92.43920  34.89977
# 2    AZ     Arizona   04 -111.66457  34.29323
# 3    CA  California   06 -119.60818  37.24537
# 4    CO    Colorado   08 -105.54783  38.99855
#
#                                             geometry
# 0  MULTIPOLYGON (((-88.11011 30.25891, -88.10638 ...
# 1  POLYGON ((-91.62986 36.49921, -91.62849 36.499...
# 2  POLYGON ((-110.49090 37.00361, -110.48750 37.0...
# 3  MULTIPOLYGON (((-118.42620 32.79973, -118.4263...
# 4  POLYGON ((-106.87560 41.00301, -106.85850 41.0...

# %% [markdown]
# We are going to clip Hawaii and Alaska and add them separately.

# %%
alaska_gdf = gdf[gdf.STATE=='AK']
alaska_gdf = alaska_gdf.merge(df_test, on="STATE")
#clipping some of the western islands to make it fit better
polygon = Polygon([(-170,50),(-170,72),(-140, 72),(-140,50)])
alaska_gdf = alaska_gdf.clip(polygon)
alaska_gdf
alaska_gdf.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: >

# %%
hawaii_gdf = gdf[gdf.STATE=='HI']
hawaii_gdf = hawaii_gdf.merge(df_test, on="STATE")
hawaii_gdf
hawaii_gdf.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: >

# %% [markdown]
# Removing Alaska and Hawaii from the table due to mapping errors. Will add back later separately.

# %%
gdf_test = gdf.drop(gdf[gdf['STATE'] == 'AK'].index)
gdf_test = gdf_test.drop(gdf_test[gdf_test['STATE'] == 'HI'].index)
len(gdf_test)
# Out:
# 49

# %% [markdown]
# Creating the merged dataset that will include the Tax rate as a column

# %%
df_test = df[['STATE','2022']].copy()
df_test.head()
# Out:
#   STATE  2022
# 0    AL  6.50
# 1    AK  5.34
# 2    AZ  4.90
# 3    AR  3.65
# 4    CA  8.84

# %%
gdf_new = gdf_test.merge(df_test, on="STATE")
gdf_new
# Out:
#    STATE                  NAME FIPS        LON       LAT  \
# 0     AL               Alabama   01  -86.82676  32.79354
# 1     AR              Arkansas   05  -92.43920  34.89977
# 2     AZ               Arizona   04 -111.66457  34.29323
# 3     CA            California   06 -119.60818  37.24537
# 4     CO              Colorado   08 -105.54783  38.99855
# 5     CT           Connecticut   09  -72.72623  41.62196
# 6     DC  District of Columbia   11  -77.01464  38.90932
# 7     DE              Delaware   10  -75.50592  38.99559
# 8     FL               Florida   12  -82.50934  28.67402
# 9     GA               Georgia   13  -83.44848  32.65155
# 10    IA                  Iowa   19  -93.50003  42.07463
# 11    ID                 Idaho   16 -114.65933  44.38907
# 12    IL              Illinois   17  -89.19838  40.06501
# 13    IN               Indiana   18  -86.27548  39.90801
# 14    KS                Kansas   20  -98.38019  38.48471
# 15    KY              Kentucky   21  -85.29046  37.52668
# 16    LA             Louisiana   22  -92.02905  31.08910
# 17    MA         Massachusetts   25  -71.81423  42.25788
# 18    ME                 Maine   23  -69.22999  45.38046
# 19    MI              Michigan   26  -85.43675  44.34717
# 20    MN             Minnesota   27  -94.31357  46.31189
# 21    MS           Mississippi   28  -89.66553  32.75201
# 22    MT               Montana   30 -109.64507  47.03350
# 23    NC        North Carolina   37  -79.37865  35.54369
# 24    ND          North Dakota   38 -100.46935  47.44626
# 25    NE              Nebraska   31  -99.81058  41.52709
# 26    NH         New Hampshire   33  -71.57754  43.68556
# 27    NJ            New Jersey   34  -74.66876  40.20049
# 28    NM            New Mexico   35 -106.10837  34.42137
# 29    NV                Nevada   32 -116.65539  39.35648
# 30    NY              New York   36  -75.51491  42.94796
# 31    OH                  Ohio   39  -82.79002  40.29120
# 32    OK              Oklahoma   40  -97.50819  35.58345
# 33    OR                Oregon   41 -120.55232  43.93589
# 34    PA          Pennsylvania   42  -77.79930  40.87368
# 35    RI          Rhode Island   44  -71.55579  41.67544
# 36    SD          South Dakota   46 -100.23048  44.43614
# 37    TN             Tennessee   47  -86.34332  35.84299
# 38    TX                 Texas   48  -99.35939  31.49422
# 39    UT                  Utah   49 -111.67822  39.32379
# 40    VA              Virginia   51  -78.82957  37.51637
# 41    VT               Vermont   50  -72.66273  44.07511
# 42    WA            Washington   53 -120.43997  47.38076
# 43    WI             Wisconsin   55  -90.01144  44.63725
# 44    WV         West Virginia   54  -80.61372  38.64259
# 45    WY               Wyoming   56 -107.55144  42.99963
# 46    MO              Missouri   29  -92.38554  38.32080
# 47    SC        South Carolina   45  -80.89899  33.93574
# 48    MD              Maryland   24  -76.78588  39.04533
#
#                                              geometry  2022
# 0   MULTIPOLYGON (((-88.11011 30.25891, -88.10638 ...  6.50
# 1   POLYGON ((-91.62986 36.49921, -91.62849 36.499...  3.65
# 2   POLYGON ((-110.49090 37.00361, -110.48750 37.0...  4.90
# 3   MULTIPOLYGON (((-118.42620 32.79973, -118.4263...  8.84
# 4   POLYGON ((-106.87560 41.00301, -106.85850 41.0...  4.55
# 5   MULTIPOLYGON (((-73.62247 40.98430, -73.62209 ...  7.50
# 6   MULTIPOLYGON (((-77.03097 38.80826, -77.03110 ...  8.25
# 7   MULTIPOLYGON (((-75.22731 38.58854, -75.22744 ...  8.70
# 8   MULTIPOLYGON (((-81.96339 24.52110, -81.96374 ...  5.50
# 9   MULTIPOLYGON (((-81.49619 30.73234, -81.49648 ...  5.75
# 10  POLYGON ((-92.44900 43.50181, -92.44550 43.500...  8.10
# 11  POLYGON ((-116.06000 49.00081, -116.04919 49.0...  6.00
# 12  POLYGON ((-90.64000 42.50841, -90.63660 42.508...  9.50
# 13  POLYGON ((-86.08849 41.76071, -86.06750 41.760...  4.90
# 14  POLYGON ((-101.87420 40.00311, -101.86520 40.0...  5.50
# 15  MULTIPOLYGON (((-89.48360 36.50021, -89.48499 ...  5.00
# 16  MULTIPOLYGON (((-89.41367 28.92076, -89.41422 ...  5.33
# 17  MULTIPOLYGON (((-70.81094 41.26176, -70.81018 ...  8.00
# 18  MULTIPOLYGON (((-70.42468 43.36591, -70.42200 ...  7.17
# 19  MULTIPOLYGON (((-83.43458 41.73714, -83.43464 ...  6.00
# 20  MULTIPOLYGON (((-92.20329 46.70404, -92.20239 ...  9.80
# 21  MULTIPOLYGON (((-88.62128 30.35913, -88.62421 ...  3.00
# 22  POLYGON ((-114.32130 49.00081, -114.26040 49.0...  6.75
# 23  MULTIPOLYGON (((-77.50814 34.45068, -77.50844 ...  2.50
# 24  POLYGON ((-97.23270 48.99921, -97.23390 48.996...  3.09
# 25  POLYGON ((-103.96180 43.00156, -103.96079 43.0...  6.70
# 26  POLYGON ((-71.08420 45.30531, -71.08210 45.288...  7.60
# 27  MULTIPOLYGON (((-74.90399 38.95216, -74.90373 ...  8.62
# 28  POLYGON ((-108.37560 36.99951, -108.35719 36.9...  5.35
# 29  POLYGON ((-114.81620 42.00201, -114.80900 42.0...  0.00
# 30  MULTIPOLYGON (((-73.72681 40.59421, -73.72669 ...  6.88
# 31  MULTIPOLYGON (((-82.65704 41.43713, -82.65740 ...  0.00
# 32  POLYGON ((-100.08950 37.00231, -100.05299 37.0...  4.00
# 33  MULTIPOLYGON (((-124.21268 42.00535, -124.2131...  7.10
# 34  MULTIPOLYGON (((-79.76220 42.26891, -79.76200 ...  9.99
# 35  MULTIPOLYGON (((-71.56863 41.22551, -71.56779 ...  7.00
# 36  POLYGON ((-102.64259 45.94541, -102.63840 45.9...  0.00
# 37  POLYGON ((-88.04480 36.67801, -88.02460 36.677...  6.50
# 38  MULTIPOLYGON (((-97.19970 25.99932, -97.19998 ...  0.00
# 39  POLYGON ((-111.04929 42.00161, -111.04680 42.0...  4.85
# 40  MULTIPOLYGON (((-77.92809 39.19681, -77.92400 ...  6.00
# 41  POLYGON ((-72.83210 45.01641, -72.82570 45.016...  7.17
# 42  MULTIPOLYGON (((-123.34106 46.15892, -123.3413...  0.00
# 43  MULTIPOLYGON (((-87.81677 42.59232, -87.81697 ...  7.90
# 44  POLYGON ((-80.52020 40.63791, -80.51900 40.634...  6.50
# 45  POLYGON ((-109.10339 45.00591, -109.08920 45.0...  0.00
# 46  POLYGON ((-91.72970 40.61361, -91.72010 40.601...  4.00
# 47  MULTIPOLYGON (((-82.38064 35.20132, -82.37949 ...  5.00
# 48  MULTIPOLYGON (((-75.88359 37.90867, -75.88402 ...  8.25

# %% [markdown]
# Plotting the values on a geographical map we get a heatmap:

# %%
# Print the map
# Set the range for the choropleth
title = 'Tax rate in 2022'
col = '2022'
vmin = gdf_new[col].min()
vmax = gdf_new[col].max()
cmap = 'GnBu'
# Create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(20, 8))
# Remove the axis
ax.axis('off')
gdf_new.plot(column=col, ax=ax, edgecolor='0.8', linewidth=1, cmap=cmap, legend=True)
# Add a title
ax.set_title(title, fontdict={'fontname': 'Times New Roman','fontsize': '25', 'fontweight': '3'})
# Create an annotation for the data source

#Add Alaska
akax = fig.add_axes([0.1, 0.17, 0.2, 0.19])   
akax.axis('off')
alaska_gdf.plot(column=alaska_gdf["2022"], cmap="GnBu", ax=akax, linewidth=1, edgecolor='0.8')

#Add Hawaii
hiax = fig.add_axes([.28, 0.20, 0.1, 0.1])      
hiax.axis('off')
hawaii_gdf.plot(column=hawaii_gdf["2022"], cmap="GnBu", ax=hiax, linewidth=1, edgecolor='0.8')
# Out:
# <img src="data:image/png;base64,..." width="2000">
# <Axes: >

# %%
title = 'Tax rate in 2022'
col = '2022'
vmin = gdf_new[col].min()
vmax = gdf_new[col].max()
cmap = 'GnBu'

# Create a figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(20, 8))

# Remove the axis
ax.axis('off')

# Plot the choropleth map with the specified column, colormap, and legend
gdf_new.plot(column=col, ax=ax, edgecolor='0.8', linewidth=1, cmap=cmap, legend=True)

# Add a title
ax.set_title(title, fontdict={'fontname': 'Times New Roman', 'fontsize': 25, 'fontweight': 'bold'})

# Create an annotation for the data source (you can add this as needed)

# Add Alaska on the same scale
akax = fig.add_axes([0.1, 0.15, 0.15, 0.15])
akax.axis('off')
alaska_gdf.plot(column=alaska_gdf["2022"], cmap=cmap, ax=akax, linewidth=1, edgecolor='0.8')

# Add Hawaii on the same scale
hiax = fig.add_axes([0.25, 0.15, 0.15, 0.15])
hiax.axis('off')
hawaii_gdf.plot(column=hawaii_gdf["2022"], cmap=cmap, ax=hiax, linewidth=1, edgecolor='0.8')

# Display the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
alaska_gdf
# Out:
#   STATE    NAME FIPS         LON        LAT  \
# 0    AK  Alaska   02 -152.255721  64.242373
#
#                                             geometry  2022
# 0  MULTIPOLYGON (((-169.16139 52.79556, -169.1610...  5.34

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable

# Set title, column name, vmin, vmax, and colormap
title = 'Tax rate in 2022'
col = '2022'
vmin = gdf_new[col].min()
vmax = gdf_new[col].max()
cmap = 'GnBu'

# Create a figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(20, 8))

# Remove the axis
ax.axis('off')

# Create a color normalization for the contiguous states
norm = Normalize(vmin=vmin, vmax=vmax)

# Plot the choropleth map with the specified column, colormap, and legend for contiguous states
gdf_new.plot(column=col, ax=ax, edgecolor='0.8', linewidth=1, cmap=cmap, legend=True, norm=norm)

# Add a title
ax.set_title(title, fontdict={'fontname': 'Times New Roman', 'fontsize': 25, 'fontweight': 'bold'})

# Create an annotation for the data source (you can add this as needed)

# Add Alaska
akax = fig.add_axes([0.1, 0.17, 0.2, 0.19])
akax.axis('off')
alaska_gdf.plot(column=alaska_gdf["2022"], cmap=cmap, ax=akax, linewidth=1, edgecolor='0.8')

# Add Hawaii
hiax = fig.add_axes([0.28, 0.20, 0.1, 0.1])
hiax.axis('off')
hawaii_gdf.plot(column=hawaii_gdf["2022"], cmap=cmap, ax=hiax, linewidth=1, edgecolor='0.8')

# Create a ScalarMappable for Alaska and Hawaii
sm = ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # Pass an empty array to ScalarMappable

# Create a color bar for Alaska and Hawaii
cbar = plt.colorbar(sm, ax=[akax, hiax], orientation='vertical', pad=0.03)
cbar.set_label('Tax Rate')

# Display the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
from matplotlib.widgets import Button, Slider

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider

x = np.linspace(0, 3, 300)
y = np.sin(5 * np.pi * x)

fig, ax = plt.subplots()
l, = ax.plot(x, y)
plt.show()

# %%
fig.subplots_adjust(bottom=0.2)

# %%
x = np.linspace(0, 3, 300)
y = np.sin(5 * np.pi * x)

fig, ax = plt.subplots()
fig.subplots_adjust(bottom=0.2)
l, = ax.plot(x, y)

def onChange(value):
    l.set_ydata(np.sin(value * np.pi * x))
    fig.canvas.draw_idle()

slideraxis = fig.add_axes([0.25, 0.1, 0.65, 0.03])
slider = Slider(slideraxis, label='Frequency [Hz]',
                valmin=0, valmax=10, valinit=0)
slider.on_changed(onChange)
plt.show()

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
