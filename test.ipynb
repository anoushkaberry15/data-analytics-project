# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("taxrates.csv")
df.head()
# Out:
#         State  2000   2001      2002      2003      2004      2005      2006  \
# 0     Alabama  5.00  5.000  6.000000  5.000000  6.500000  6.500000  6.500000
# 1      Alaska  5.20  5.200  5.440000  5.440000  5.440000  5.440000  5.440000
# 2     Arizona  8.00  7.968  6.968000  6.970000  6.970000  6.970000  6.970000
# 3    Arkansas  3.75  3.750  3.916667  3.916667  3.916667  3.916667  3.916667
# 4  California  8.84  8.840  8.840000  8.840000  8.840000  8.840000  8.840000
#
#        2007      2008  ...      2014      2015      2016      2017      2018  \
# 0  6.500000  6.500000  ...  6.500000  6.500000  6.500000  6.500000  6.500000
# 1  5.440000  5.440000  ...  5.440000  5.340000  5.340000  5.340000  5.340000
# 2  6.970000  6.970000  ...  6.500000  5.500000  5.500000  4.900000  4.900000
# 3  3.916667  3.916667  ...  3.916667  3.916667  3.916667  3.916667  3.916667
# 4  8.840000  8.840000  ...  8.840000  8.840000  8.840000  8.840000  8.840000
#
# ...

# %%
df = df.round(2)
df.head()
# Out:
#         State  2000  2001  2002  2003  2004  2005  2006  2007  2008  ...  \
# 0     Alabama  5.00  5.00  6.00  5.00  6.50  6.50  6.50  6.50  6.50  ...
# 1      Alaska  5.20  5.20  5.44  5.44  5.44  5.44  5.44  5.44  5.44  ...
# 2     Arizona  8.00  7.97  6.97  6.97  6.97  6.97  6.97  6.97  6.97  ...
# 3    Arkansas  3.75  3.75  3.92  3.92  3.92  3.92  3.92  3.92  3.92  ...
# 4  California  8.84  8.84  8.84  8.84  8.84  8.84  8.84  8.84  8.84  ...
#
#    2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# 0  6.50  6.50  6.50  6.50  6.50  6.50  6.50  6.50  6.50  6.50
# 1  5.44  5.34  5.34  5.34  5.34  5.34  5.34  5.34  5.34  5.34
# 2  6.50  5.50  5.50  4.90  4.90  4.90  4.90  4.90  4.90  4.90
# 3  3.92  3.92  3.92  3.92  3.92  3.92  3.92  3.87  3.65  3.55
# 4  8.84  8.84  8.84  8.84  8.84  8.84  8.84  8.84  8.84  8.84
#
# [5 rows x 25 columns]

# %%
df_transposed = df.T 
df_transposed.columns=df_transposed.iloc[0]
df_transposed = df_transposed.tail(-1)
df_transposed.head()
# Out:
# State Alabama Alaska Arizona Arkansas California Colorado Connecticut  \
# 2000      5.0    5.2     8.0     3.75       8.84     4.75         8.5
# 2001      5.0    5.2    7.97     3.75       8.84     4.63         7.5
# 2002      6.0   5.44    6.97     3.92       8.84     4.63         7.5
# 2003      5.0   5.44    6.97     3.92       8.84     4.63         7.5
# 2004      6.5   5.44    6.97     3.92       8.84     4.63         7.5
#
# State Delaware Florida Georgia  ... Tennessee Texas Utah Vermont Virginia  \
# 2000       8.7     5.5     6.0  ...       6.0   0.0  5.0    8.38      6.0
# 2001       8.7     5.5     6.0  ...       6.0   0.0  5.0    8.38      6.0
# 2002       8.7     5.5     6.0  ...       6.0   0.0  5.0    8.51      6.0
# 2003       8.7     5.5     6.0  ...       6.0   0.0  5.0    8.51      6.0
# 2004       8.7     5.5     6.0  ...       6.5   0.0  5.0    8.51      6.0
#
# State Washington West Virginia Wisconsin  Wyoming District of Columbia
# ...

# %%
df_transposed.plot()
# Out:
# <Axes: >

# %%
import geopandas as gpd

# %%
shapefile = 'data/cb_2018_us_state_500k.shp'
gdf = gpd.read_file(shapefile)
gdf
#drop Puerto rico, American Samoa, US Virgin Islands, Guam, Commonwealth of the northern mariana islands from file
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS  \
# 0       28  01779790  0400000US28    28     MS
# 1       37  01027616  0400000US37    37     NC
# 2       40  01102857  0400000US40    40     OK
# 3       51  01779803  0400000US51    51     VA
# 4       54  01779805  0400000US54    54     WV
# 5       22  01629543  0400000US22    22     LA
# 6       26  01779789  0400000US26    26     MI
# 7       25  00606926  0400000US25    25     MA
# 8       16  01779783  0400000US16    16     ID
# 9       12  00294478  0400000US12    12     FL
# 10      31  01779792  0400000US31    31     NE
# 11      53  01779804  0400000US53    53     WA
# 12      35  00897535  0400000US35    35     NM
# 13      72  01779808  0400000US72    72     PR
# 14      46  01785534  0400000US46    46     SD
# 15      48  01779801  0400000US48    48     TX
# 16      06  01779778  0400000US06    06     CA
# 17      01  01779775  0400000US01    01     AL
# 18      13  01705317  0400000US13    13     GA
# ...

# %%
df_test = df[['State','2022']].copy()
df_test.head()
# Out:
#         State  2022
# 0     Alabama  6.50
# 1      Alaska  5.34
# 2     Arizona  4.90
# 3    Arkansas  3.65
# 4  California  8.84

# %%
merged = gdf.merge(df_test)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 merged = gdf.merge(df_test)
#
# File ~/anaconda3/lib/python3.11/site-packages/geopandas/geodataframe.py:1574, in GeoDataFrame.merge(self, *args, **kwargs)
#    1556 def merge(self, *args, **kwargs):
#    1557     r"""Merge two ``GeoDataFrame`` objects with a database-style join.
#    1558
#    1559     Returns a ``GeoDataFrame`` if a geometry column is present; otherwise,
#    (...)
#    1572     for more details.
#    1573     """
# -> 1574     result = DataFrame.merge(self, *args, **kwargs)
#    1575     geo_col = self._geometry_column_name
#    1576     if isinstance(result, DataFrame) and geo_col in result:
#
# ...
